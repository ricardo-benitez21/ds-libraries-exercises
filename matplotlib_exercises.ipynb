# %% [markdown]
# # 2. Create and label 4 separate charts with the following equations (choose a range for x that makes sense):
#
# * y=√x
# * y=x^3
# * y=2^x
# * y=1/(x+1)
#
# # You can use functions from the math module to help implement some of the equations above.

# %%
import pandas as pd
import numpy as np
import env
from pydataset import data 
import matplotlib.pyplot as plt
import math

# %%
x = np.array(list(range(10)))
y = x ** 0.5
y           

plt.plot(x,y)
plt.title('y=1/(x+1)');

# %%
x = np.array(list(range(10)))
y = x ** 3
y           

plt.plot(x,y);
plt.title('Plot of y=x^3');

# %%
x = np.array(list(range(10)))
y = 2 ** x
y           

plt.plot(x,y);
plt.title('Plot of y=2^x');

# %%
x = np.array(list(range(10)))
y = 1 / (x+1)
y           

plt.plot(x,y);
plt.title('Plot of y=1/(x+1)');

# %% [markdown]
# # 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,4,1) #subplot(#ofrows, #ofcolumns,#position of plot)

x = np.array(range(0,11))
y = x**0.5
plt.plot(x,y)

plt.subplot(1,4,2)
x = np.array(range(-10,11))
y = x**3
plt.plot(x,y)

plt.subplot(143)
x = np.array(range(0,11))
y = 2**x
plt.plot(x,y)

plt.subplot(144)
x = np.array(range(-10,10))
y = 1 / (x+1)
plt.plot(x,y)

# plt.title('test title')
plt.suptitle('four subplots') #title for subplots
plt.tight_layout() #ensures i can see my axises
plt.show()
# Out:
# /var/folders/30/4qhjzk6n3zl1z989qrk83yym0000gn/T/ipykernel_57497/1332221202.py:20: RuntimeWarning: divide by zero encountered in divide
#   y = 1 / (x+1)
